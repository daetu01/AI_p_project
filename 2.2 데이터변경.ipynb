# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/student.csv')
display(df)
# Out:
#     이름   학과   성적
# 0  아이유  국문학  3.0
# 1  김연아   수학  1.9
# 2  홍길동  컴퓨터  3.5
# 3  장범준   철학  2.7
# 4  강감찬  경영학  4.0

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\One'

# %%
# ' 등급' 컬럼 생성
df['등급'] = 'A' #새로운 컬럼 명시 후 값 부여
display(df)
# Out:
#     이름   학과   성적 등급
# 0  아이유  국문학  3.0  A
# 1  김연아   수학  1.9  A
# 2  홍길동  컴퓨터  3.5  A
# 3  장범준   철학  2.7  A
# 4  강감찬  경영학  4.0  A

# %%
grade = np.array(['B','D','B','C','A'])
df['등급'] = grade
display(df)
# Out:
#     이름   학과   성적 등급
# 0  아이유  국문학  3.0  B
# 1  김연아   수학  1.9  D
# 2  홍길동  컴퓨터  3.5  B
# 3  장범준   철학  2.7  C
# 4  강감찬  경영학  4.0  A

# %%
age = pd.Series([21,20,24,23,28])
df['나이'] = age

# %%
display(df)
# Out:
#     이름   학과   성적 등급  나이
# 0  아이유  국문학  3.0  B  21
# 1  김연아   수학  1.9  D  20
# 2  홍길동  컴퓨터  3.5  B  24
# 3  장범준   철학  2.7  C  23
# 4  강감찬  경영학  4.0  A  28

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ['one','two','three','four','five']
df
# Out:
#         이름   학과   성적 등급  나이
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.9  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
sex = pd.Series(['여자','여자','남자','남자','남자'])
df['성별'] = sex
display(df)
# Out:
#         이름   학과   성적 등급  나이   성별
# one    아이유  국문학  3.0  B  21  NaN
# two    김연아   수학  1.9  D  20  NaN
# three  홍길동  컴퓨터  3.5  B  24  NaN
# four   장범준   철학  2.7  C  23  NaN
# five   강감찬  경영학  4.0  A  28  NaN

# %%
sex.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print('시리즈 sex의 인덱스 ---> ', sex.index)
print('데이터프레임 df의 인덱스 ---> ', df.index)
# Out:
# 시리즈 sex의 인덱스 --->  RangeIndex(start=0, stop=5, step=1)
# 데이터프레임 df의 인덱스 --->  Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
sex.index = df.index
df['성별'] = sex
display(df)
# Out:
#         이름   학과   성적 등급  나이  성별
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
df.reset_index(inplace=True)  # inplace 인수를 줘야 바뀜. 
df.reset_index()
# Out:
#    level_0  index   이름   학과   성적 등급  나이  성별
# 0        0    one  아이유  국문학  3.0  B  21  여자
# 1        1    two  김연아   수학  1.9  D  20  여자
# 2        2  three  홍길동  컴퓨터  3.5  B  24  남자
# 3        3   four  장범준   철학  2.7  C  23  남자
# 4        4   five  강감찬  경영학  4.0  A  28  남자

# %%
df
# Out:
#    index   이름   학과   성적 등급  나이  성별
# 0    one  아이유  국문학  3.0  B  21  여자
# 1    two  김연아   수학  1.9  D  20  여자
# 2  three  홍길동  컴퓨터  3.5  B  24  남자
# 3   four  장범준   철학  2.7  C  23  남자
# 4   five  강감찬  경영학  4.0  A  28  남자

# %%
# df.set_index('index', inplace=True)
df.set)undex('이름')
# Out:
#   File "C:\Users\One\AppData\Local\Temp\ipykernel_8436\2379259540.py", line 2
#     df.set)undex('이름')
#           ^
# SyntaxError: invalid syntax

# %%
df.set_index('이름')
# Out:
#      index   학과   성적 등급  나이  성별
# 이름
# 아이유    one  국문학  3.0  B  21  여자
# 김연아    two   수학  1.9  D  20  여자
# 홍길동  three  컴퓨터  3.5  B  24  남자
# 장범준   four   철학  2.7  C  23  남자
# 강감찬   five  경영학  4.0  A  28  남자

# %%
df.set_index('index', inplace=True)

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
df.drop('성별', axis=1)
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.9  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
df.drop('성별', axis='columns')
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.9  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
df.drop('one', axis = 0)
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.9  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  남자

# %%
import pandas as pd
import json
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8436\705113211.py in <module>
#       1 import pandas as pd
#       2 import json
# ----> 3 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
import pandas as pd

# %%
import json
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10852\463785090.py in <module>
#       1 import json
# ----> 2 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10852\1724168889.py in <module>
# ----> 1 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25736\2072270154.py in <module>
# ----> 1 import requests
#
# ~\anaconda3\envs\dx_env\lib\site-packages\requests\__init__.py in <module>
#      41 import warnings
#      42
# ---> 43 import urllib3
#      44
#      45 from .exceptions import RequestsDependencyWarning
#
# ~\anaconda3\envs\dx_env\lib\site-packages\urllib3\__init__.py in <module>
#      40     elif ssl.OPENSSL_VERSION_INFO < (1, 1, 1):  # Defensive:
#      41         raise ImportError(
# ---> 42             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      43             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION!r}. "
#      44             "See: https://github.com/urllib3/urllib3/issues/2168"
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'OpenSSL 1.1.0i  14 Aug 2018'. See: https://github.com/urllib3/urllib3/issues/2168

# %%
import pandas as pd

# %%
import numpy as np
import requests
import json

# %%
# open API 호출 시 필요한 정보 입력
key = 'NV6nAc815cRbHjmnzaPdjcICsUbXf97VjpHkgl3aOSer5OiM5KZl0pafE3AQlMcTzFX95FFTDAolbBeCPv45JA%3D%3D'
pageNo = 0 # 요청 변수 : 페이지 번호 입력 
row = 100 # 요청 변수 : 한 페이지 결과 수 입력 
url = f'http://api.data.go.kr/openapi/tn_pubr_public_unmanned_traffic_camera_api?serviceKey={key}&pageNo={pageNo}&numOfRows={row}&type=json'

response = requests.get(url) #full url 을 requests 라이브러리를 통해 호출

# 한글 출력 시, encoding이 필요함. 
response.encoding = 'utf-8' #utf-8으로 설정

print(response.text[0:400])
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE","type":"json"},"body":{"items":[{"mnlssRegltCameraManageNo":"P-7739","ctprvnNm":"경기도","signguNm":"고양시","roadKnd":"시도","roadRouteNo":"","roadRouteNm":"킨텍스로","roadRouteDrc":"3","rdnmadr":"","lnmadr":"경기도 고양시 일산서구 대화동 2603","latitude":"37.66585766","longitude":"126.7510974","itlpc":"일산서구 대화동 2603 (한화꿈에그린 106동앞)","regltSe":"4","lmtt

# %%
# 2. 결과 객체에 있는 데이터 (json) 조회 
resulting_dict = json.loads(response.text) # json을 dict 타입으로 바꾸는 함수
#print(resulting_dict['header'])
resulting_dict.keys()
# Out:
# dict_keys(['response'])

# %%
resulting_dict['response'].keys()
# Out:
# dict_keys(['header', 'body'])

# %%
resulting_dict['response']['body'].keys()
# Out:
# dict_keys(['items', 'totalCount', 'numOfRows', 'pageNo'])

# %%
#resulting_dic['response']['body']['items']

# %%
#첫번째 아이템 호출
resulting_dict['response']['body']['items'][0]
# Out:
# {'mnlssRegltCameraManageNo': 'P-7739',
#  'ctprvnNm': '경기도',
#  'signguNm': '고양시',
#  'roadKnd': '시도',
#  'roadRouteNo': '',
#  'roadRouteNm': '킨텍스로',
#  'roadRouteDrc': '3',
#  'rdnmadr': '',
#  'lnmadr': '경기도 고양시 일산서구 대화동 2603',
#  'latitude': '37.66585766',
#  'longitude': '126.7510974',
#  'itlpc': '일산서구 대화동 2603 (한화꿈에그린 106동앞)',
#  'regltSe': '4',
#  'lmttVe': '0',
#  'regltSctnLcSe': '',
#  'ovrspdRegltSctnLt': '',
#  'prtcareaType': '',
#  'installationYear': '2019',
#  'institutionNm': '경기도 고양시',
#  'phoneNumber': '031-8075-2578',
#  'referenceDate': '2023-11-24',
#  'insttCode': '3940000'}

# %%
# 주소, 카메라 위치, 위도, 경도의 정보만 출력

address_list = []
location_list = []
latitude_list = []
longitude_list = []

#dictionary 속 데이터 정보 입력
for tmp in resulting_dict['response']['body']['items']:
    address_list.append(tmp['rdnmadr'])
    location_list.append(tmp['itlpc'])
    latitude_list.append(tmp['latitude'])
    longitude_list.append(tmp['longitude'])

print(address_list[:10])
print(location_list[:10])
print(longitude_list[:10])
# Out:
# ['', '', '', '', '', '', '', '', '', '']
# ['일산서구 대화동 2603 (한화꿈에그린 106동앞)', '일산서구 대화동 2603-2 (한화꿈에그린 102동앞)', '대화동 1099-7 현대모터스 스튜디오 건너편', '대화동 2734번지 한국지역난방공사 열공급시설 삼거리', '일산서구 중앙로 1600 일산서구청(신청사) 1(대화동2428 일산서구청 신청사 옆)', '일산서구 중앙로 1600 일산서구청(신청사) 2', '일산서구 대화동 2288-7 (문촌19단지 사거리) (5대)', '일산서구 대화동 2307-15 (대방디엠시티 102동 옆) (4대)', '가좌동 360-1송포초교 정문(가좌동 355-1 송포초등학교 정문앞)', '가좌동 391-1 송포초교 후문(가좌동 355-1 송포초등학교 후문앞)']
# ['126.7510974', '126.7510974', '126.7479285', '126.7404425', '126.745242', '126.745242', '126.7509003', '126.7484978', '126.7220093', '126.7201958']

# %%
# dataframe으로 변환
df = pd.DataFrame({
    'address' : address_list, 
    'location' : location_list, 
    'latitude' : latitude_list, 
    'longitude' : longitude_list
})

display(df)
# Out:
#    address                                         location     latitude  \
# 0                              일산서구 대화동 2603 (한화꿈에그린 106동앞)  37.66585766
# 1                            일산서구 대화동 2603-2 (한화꿈에그린 102동앞)  37.66585766
# 2                                 대화동 1099-7 현대모터스 스튜디오 건너편   37.6651343
# 3                             대화동 2734번지 한국지역난방공사 열공급시설 삼거리  37.66213291
# 4           일산서구 중앙로 1600 일산서구청(신청사) 1(대화동2428 일산서구청 신청사 옆)  37.67791456
# ..     ...                                              ...          ...
# 95             대화동 2607 킨텍스 지하차도 부근(대화동 2600-3 킨텍스 지하차도 주변)  37.66624826
# 96                                      대화동 2306-2 (킨텍스북문1)    37.671585
# 97                                  일산서구 대화동 2202-2 (우리은행앞)  37.67582142
# 98                                    대화동 2600-6 (현대자동차 정문)  37.66733286
# 99                                    대화동 2600-6 (현대자동차 후문)  37.66733286
#
#       longitude
# 0   126.7510974
# 1   126.7510974
# 2   126.7479285
# 3   126.7404425
# 4    126.745242
# ..          ...
# 95  126.7459032
# 96  126.7451536
# 97   126.749069
# 98  126.7482931
# 99  126.7482931
#
# [100 rows x 4 columns]
